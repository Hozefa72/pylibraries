# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
sales=pd.read_csv("Computersales.csv")
sales
# Out:
#      State ID       Contact  Sex   Age State     Product ID Product Type  \
# 0         1.0   Paul Thomas    M  43.0    OH      M01-F0024      Desktop
# 1         2.0   Margo Simms    F  37.0    WV      GT13-0024      Desktop
# 2         3.0     Sam Stine    M  26.0    PA          I3670      Desktop
# 3         4.0    Moe Eggert    M  35.0    PA          I3593       Laptop
# 4         5.0   Jessica Elk    F  55.0    PA         15M-ED       Laptop
# ..        ...           ...  ...   ...   ...            ...          ...
# 98       99.0  Mick Roberts    M  23.0    PA          BB980      Desktop
# 99      100.0   Ed Klondike    M  52.0    OH   15M-ED0023DX       Laptop
# 100     101.0    Moe Eggert    M  35.0    PA     GMA4000BST      Desktop
# 101     102.0   Jessica Elk    F  55.0    PA  AN515-55-53AG       Tablet
# 102       NaN           NaN  NaN   NaN   NaN            NaN          NaN
#
#      Sale Price  Profit     Lead     Month    Year
# ...

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
a=sns.load_dataset('car_crashes')
print(a)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# ##Distribution plots

# %%
sns.distplot(a['not_distracted'],kde=False,bins=25)
plt.show()
#the line in te graph is kde where kde=kernel density estimation
#bins refer to number of bars in a histogram
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7800\4167901163.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a['not_distracted'],kde=False,bins=25)

# %% [markdown]
# #distribution plot

# %%
sns.jointplot(x="speeding",y="alcohol",data=a,kind='hex')

# %%
#kde plot
sns.kdeplot(a['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
#pairplot
sns.pairplot(a)

# %%
tip=sns.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(tip,hue='sex',palette='Blues')

# %%
sns.rugplot(tip['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
sns.set_style('dark')
sns.set_context('paper',font_scale=1.4)
plt.figure(figsize=(8,5))
sns.jointplot(x='speeding',y='alcohol',data=a,kind='reg')
sns.despine(left=True)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import scipy

# %% [markdown]
# # Line plot

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
var=[1,2,3,4,5,6,7]
var1=[2,3,4,5,7,3,4]
plt.plot(var,var1)
plt.show()

# %%
df=pd.DataFrame({"var":var,"var1":var1})
sns.lineplot(x="var",y="var1",data=df)
plt.show()

# %%
sns.lineplot(x=var,y=var1)
plt.show()

# %%
df1=sns.load_dataset("penguins").head(20)
plt.style.use("ggplot")
sns.lineplot(x='bill_length_mm',y='bill_depth_mm',data=df1,hue="sex",size=10,style="sex",palette='plasma',markers=['.','*'],dashes=False,legend="brief")
plt.show()

# %%
df1
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %% [markdown]
# # Bar Plot

# %%
df=sns.load_dataset("penguins")
sns.barplot(x="island",y="body_mass_g",data=df,hue="sex",ci=100,hue_order=['Female','Male'],n_boot=3,orient="v")
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7800\1254811923.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.barplot(x="island",y="body_mass_g",data=df,hue="sex",ci=100,hue_order=['Female','Male'],n_boot=3,orient="v")

# %%
df=sns.load_dataset("penguins")
sns.barplot(x="bill_length_mm",y="bill_depth_mm",data=df,orient="v")
plt.show()

# %%
sns.set(style="darkgrid")
sns.barplot(x="island",y="body_mass_g",data=df,orient="v",hue='sex',palette="icefire",saturation=5,errcolor='b',dodge=False,alpha=0.5)
plt.show()

# %% [markdown]
# # histplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(df['flipper_length_mm'],bins=[170,180,190,200,210,220,230,240],kde=True,rug=True,color='g')
plt.show()

# %%
sns.distplot(df['flipper_length_mm'],bins=[170,180,190,200,210,220,230,240])
plt.show()
#it gives kernal destiny estimation graph
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7800\381844237.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['flipper_length_mm'],bins=[170,180,190,200,210,220,230,240])

# %%
sns.displot(df['flipper_length_mm'],kde=True,rug=True,color='g',log_scale=True)
plt.show()

# %% [markdown]
# # scatterplot

# %%
df=sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
m={"Male":".","Female":"o"}
sns.scatterplot(x='bill_length_mm',y='bill_depth_mm',data=df,hue='sex',style='sex',size='sex',sizes=(15,20),palette='plasma',alpha=0.75,markers=m)
plt.show()

# %% [markdown]
# # HeatMap

# %%
var=np.linspace(1,10,20).reshape(4,5)
sns.heatmap(data=var,vmin=0,vmax=20,cmap="PuOr",annot=True)#this heatmap show a matrix of 4,5 in color format 
plt.show()

# %%
var
# Out:
# array([[ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684],
#        [ 3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789],
#        [ 5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895],
#        [ 8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]])

# %%
var1=np.linspace(0,10,10).reshape(2,5)
ar=np.array([['a0','a1','a2','a3','a4'],
            ['b0','b1','b2','b3','b4']])
y={'fontsize':20,'color':'r'}
a=sns.heatmap(data=var1,vmin=0,vmax=10,cmap='ocean',annot=ar,fmt='s',annot_kws=y,linewidth=1,linecolor='k',cbar=False,xticklabels=False,yticklabels=False)
a.set(xlabel='columns',ylabel='rows')
sns.set(font_scale=1)
plt.show()

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
var=sns.load_dataset('anagrams')
var
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
df=var.drop(columns=['attnr'],axis=1).head(5)
df
# Out:
#    subidr  num1  num2  num3
# 0       1     2   4.0     7
# 1       2     3   4.0     5
# 2       3     3   5.0     6
# 3       4     5   7.0     5
# 4       5     4   5.0     8

# %%
sns.heatmap(data=df)
# Out:
# <Axes: >

# %% [markdown]
# # Count Plot

# %%
var=sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x='day',data=var)
plt.show()

# %%
df=var.groupby('day').count()
df
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Thur          62   62   62      62    62    62
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76

# %%
days=df.index
wid=0.25
plt.bar(days,df['total_bill'],color=['r','g','b','y'])
plt.show()

# %%
sns.countplot(x='time',data=var,hue='sex')
plt.show()

# %%
sns.countplot(x='day',data=var,hue='smoker')
plt.show()

# %%
#plt.figure(figsize=(10,100))
sns.countplot(y='sex',data=var,hue='smoker',palette='cool',saturation=0.75)
#a=np.arange(0,100)
#plt.yticks(ticks=a)
plt.show()

# %% [markdown]
# # Violin Plot

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x='day',y='tip',data=df,hue='time',linewidth=2)
              
a=np.arange(0,11)
plt.yticks(ticks=a)
plt.show()

# %%
df[df['day']=='Thur'].quantile(0.25)['tip']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7800\898492214.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df['day']=='Thur'].quantile(0.25)['tip']
# 2.0

# %%
sns.violinplot(x='time',y='total_bill',data=df,order=['Dinner','Lunch'],saturation=0.75,inner='quart')
b=np.arange(0,60,5)
plt.yticks(ticks=b)
plt.show()

# %%
df[df['time']=='Dinner'].quantile(0.5)['total_bill']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7800\2307003443.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df['time']=='Dinner'].quantile(0.5)['total_bill']
# 18.39

# %%
sns.violinplot(x='day',y='total_bill',data=df,hue='sex',split=True,scale='width')
plt.show()

# %%
sns.countplot(x='day',data=df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.violinplot(y='day',x='total_bill',data=df,hue='sex',split=True,scale='width')
plt.show()

# %%
sns.violinplot(x=df['total_bill'])
plt.show()

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(df,hue='sex')
plt.show()

# %%
sns.pairplot(df,vars=['total_bill','tip'],hue='sex',hue_order=['Female','Male'],palette='ocean')

# %%
sns.pairplot(df,x_vars=['total_bill','tip'],hue='sex',palette='ocean')

# %%
sns.pairplot(df,y_vars=['total_bill','tip'],hue='sex',palette='ocean')

# %%
sns.pairplot(df,hue='sex',kind='reg') #scatter,kde,hist,reg
plt.show()

# %%
sns.pairplot(df,hue='sex',kind='kde',diag_kind='hist')
plt.show()
