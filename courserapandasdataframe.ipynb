# %%
import pandas as pd

# %%
record1=pd.Series({'Name':'Hozefa',
                  'Subject':'DSA',
                  'Score':92})
record1
# Out:
# Name       Hozefa
# Subject       DSA
# Score          92
# dtype: object

# %%
record2=pd.Series({'Name':'Harshit',
                  'Subject':'DBMS',
                  'Score':90})
record3=pd.Series({'Name':"Harsha",
                  'Subject':'DCN',
                  'Score':91})

# %%
df=pd.DataFrame([record1,record2,record3],index=['S1','S2','S3'])
df
# Out:
#        Name Subject  Score
# S1   Hozefa     DSA     92
# S2  Harshit    DBMS     90
# S3   Harsha     DCN     91

# %%
records=[{'Name':'Hozefa',
                  'Subject':'DSA',
                  'Score':92},
        {'Name':'Harshit',
                  'Subject':'DBMS',
                  'Score':90},
         {'Name':"Harsha",
                  'Subject':'DCN',
                  'Score':91}]
df1=pd.DataFrame(records,index=['S1','S2','S1'])
df1
# Out:
#        Name Subject  Score
# S1   Hozefa     DSA     92
# S2  Harshit    DBMS     90
# S1   Harsha     DCN     91

# %%
type(df1.iloc[2])
#series is the type of data structure
# Out:
# pandas.core.series.Series

# %%
df1.loc['S1']
#it will an error if you put row index second and column index first
# Out:
#       Name Subject  Score
# S1  Hozefa     DSA     92
# S1  Harsha     DCN     91

# %%
df1.iloc['S2']
#this will give a type error because iloc needs an integer as an parameter
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df1.iloc['S2']
#       2 #this will give a type error because iloc needs an integer as an parameter
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:1622, in _iLocIndexer._getitem_axis(self, key, axis)
#    1620 key = item_from_zerodim(key)
#    1621 if not is_integer(key):
# -> 1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
#    1625 self._validate_integer(key, axis)
#
# ...

# %%
df.loc[0]
#this will give an key error because index is set by character not by integer
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
type(df1.loc['S1'])
#always remeber iloc needs integer as parameter and loc needs string or character as parameter

# %%
print(df1.loc['S1','Name'])
type(df1.loc['S1','Name'])
#it will give series because it returns only name columns with s1 index
# Out:
# S1    Hozefa
# S1    Harsha
# Name: Name, dtype: object
# pandas.core.series.Series

# %%
df1.T
# Out:
#              S1       S2      S1
# Name     Hozefa  Harshit  Harsha
# Subject     DSA     DBMS     DCN
# Score        92       90      91

# %%
#it will produce ke error because name is column name it come second
df1.loc['Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:162, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:203, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:211, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
# ...

# %%
print(type(df1.loc['S1']['Name']))
print(type(df1.loc['S1']))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
df1.loc[:,['Name','Subject']]
# Out:
#        Name Subject
# S1   Hozefa     DSA
# S2  Harshit    DBMS
# S1   Harsha     DCN

# %%
df1.drop('S2')
#it does not actually change the database it happenn only for an instance
# Out:
#       Name Subject  Score
# S1  Hozefa     DSA     92
# S1  Harsha     DCN     91

# %%
df1
# Out:
#        Name Subject  Score
# S1   Hozefa     DSA     92
# S2  Harshit    DBMS     90
# S1   Harsha     DCN     91

# %%
df1.drop('S2')
#now this actually drop the s2 row pr series from dataframe
# Out:
#       Name Subject  Score
# S1  Hozefa     DSA     92
# S1  Harsha     DCN     91

# %%
df1
# Out:
#        Name Subject  Score
# S1   Hozefa     DSA     92
# S2  Harshit    DBMS     90
# S1   Harsha     DCN     91

# %%
cpy=df1.copy()

# %%
cpy
# Out:
#        Name Subject  Score
# S1   Hozefa     DSA     92
# S2  Harshit    DBMS     90
# S1   Harsha     DCN     91

# %%
cpy.iloc[0,0]="Hamza"

# %%
cpy.loc['S1','Name']=["Hozefa","Harsha"]

# %%
cpy
# Out:
#        Name Subject  Score
# S1   Hozefa     DSA     92
# S2  Harshit    DBMS     90
# S1   Harsha     DCN     91

# %%
cpy.iloc[0:3:2,1]=["DSA","DCN"]

# %%
cpy
# Out:
#        Name Subject  Score
# S1   Hozefa     DSA     92
# S2  Harshit    DBMS     90
# S1   Harsha     DCN     91

# %%
cpy=cpy.drop('S1')

# %%
cpy=df1

# %%
cpy
# Out:
#        Name Subject  Score
# S1   Hozefa     DSA     92
# S2  Harshit    DBMS     90
# S1   Harsha     DCN     91

# %%
del cpy['Score']
#it is not a function so no need of curly bracket

# %%
cpy.set_index("Name", inplace=True)
cpy
# Out:
#         Subject
# Name
# Hozefa      DSA
# Harshit    DBMS
# Harsha      DCN

# %%
#adding new column
df['Ranking']=[1,3,2]

# %%
df
#dataframe is mutable that it means we can change value of dataframe as well as column name
# Out:
#        Name Subject  Score  Ranking
# S1   Hozefa     DSA     92        1
# S2  Harshit    DBMS     90        3
# S3   Harsha     DCN     91        2

# %%
df.iloc[2,0]="Harsha"

# %%
df
# Out:
#        Name Subject  Score  Ranking
# S1   Hozefa     DSA     92        1
# S2  Harshit    DBMS     90        3
# S3   Harsha     DCN     91        2

# %%
df.set_index("Index")
#it will give an error because there is no column name as "Index"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.set_index("Index")
#       2 #it will give an error because there is no column name as "Index"
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:6012, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    6009                 missing.append(col)
#    6011 if missing:
# ...

# %%
df.rename(index={"S1":"A1","S2":"A2","S3":"A3"})

# %%
df2=pd.read_csv('Admission_Predict.csv')
df2

# %%
# !cat Admission_Predict.csv

# %%
df2.set_index('Serial No.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df2.set_index('Serial No.')
#
# NameError: name 'df2' is not defined

# %%
df3=pd.read_csv('Admission_Predict.csv',index_col=0)
df3.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
df2=df2.rename(columns={'SOP':'Statement of Purpose','LOR':'Letter of Recommendation'})
df2
#only sop is changing lor is not changing why so it reason is given in below cell
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df2=df2.rename(columns={'SOP':'Statement of Purpose','LOR':'Letter of Recommendation'})
#       2 df2
#       3 #only sop is changing lor is not changing why so it reason is given in below cell
#
# NameError: name 'df2' is not defined

# %%
df2.columns
#here we see a space after lor that is why it is not working
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df2.columns
#       2 #here we see a space after lor that is why it is not working
#
# NameError: name 'df2' is not defined

# %%
df2=df2.rename(columns={'SOP':'Statement of Purpose','LOR ':'Letter of recommendation'})
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df2=df2.rename(columns={'SOP':'Statement of Purpose','LOR ':'Letter of recommendation'})
#       2 df2
#
# NameError: name 'df2' is not defined

# %%
df2=df2.rename(mapper=str.strip,axis='columns')
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df2=df2.rename(mapper=str.strip,axis='columns')
#       2 df2
#
# NameError: name 'df2' is not defined

# %%
cols=df2.columns
cols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 cols=df2.columns
#       2 cols
#
# NameError: name 'df2' is not defined

# %%
cols=[x.lower().strip() for x in cols]
df2.columns=cols
df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 cols=[x.lower().strip() for x in cols]
#       2 df2.columns=cols
#       3 df2.head()
#
# NameError: name 'cols' is not defined

# %% [markdown]
# ##quering a datadrame

# %%
df4=pd.read_csv('Admission_Predict.csv')
df4.columns=[x.lower().strip() for x in df4.columns]
df4.head()
# Out:
#    serial no.  gre score  toefl score  university rating  sop  lor  cgpa  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    research  chance of admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %%
df4=df4.set_index('serial no.')

# %%
#creating boolean mask
bool_mask=df4.loc[:,'chance of admit']>0.7
bool_mask
# Out:
# serial no.
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398     True
# 399    False
# 400     True
# Name: chance of admit, Length: 400, dtype: bool

# %%
df4.where(bool_mask)
#it is used in data hiding it does not show the record of that row whose row's chance of admit is less than 0.7
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# serial no.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 5                 NaN          NaN                NaN  NaN  NaN   NaN
# ...               ...          ...                ...  ...  ...   ...
# 396             324.0        110.0                3.0  3.5  3.5  9.04
# 397             325.0        107.0                3.0  3.0  3.5  9.11
# 398             330.0        116.0                4.0  5.0  4.5  9.45
# 399               NaN          NaN                NaN  NaN  NaN   NaN
# 400             333.0        117.0                4.0  5.0  4.0  9.66
#
#             research  chance of admit
# serial no.
# 1                1.0             0.92
# ...

# %%
df4.where(bool_mask).dropna().head(20)
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# serial no.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 6               330.0        115.0                5.0  4.5  3.0  9.34
# 7               321.0        109.0                3.0  3.0  4.0  8.20
# 12              327.0        111.0                4.0  4.0  4.5  9.00
# 13              328.0        112.0                4.0  4.0  4.5  9.10
# 23              328.0        116.0                5.0  5.0  5.0  9.50
# 24              334.0        119.0                5.0  5.0  4.5  9.70
# 25              336.0        119.0                5.0  4.0  3.5  9.80
# 26              340.0        120.0                5.0  4.5  4.5  9.60
# ...

# %%
df4[df4['chance of admit']>0.7].head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# serial no.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
#
#             research  chance of admit
# serial no.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 6                  1             0.90

# %%
df4[df4['gre score']>320]
#it is known as bollean mask
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# serial no.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
# 7                 321          109                  3  3.0  4.0  8.20
# ...               ...          ...                ...  ...  ...   ...
# 395               329          111                  4  4.5  4.0  9.23
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 400               333          117                  4  5.0  4.0  9.66
#
#             research  chance of admit
# serial no.
# 1                  1             0.92
# ...

# %%
df4[df4['chance of admit']>0.7 and df4['chance of admit']<0.9]
#it will give an error because it cannot compare two series
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df4[df4['chance of admit']>0.7 and df4['chance of admit']<0.9]
#       2 #it will give an error because it cannot compare two series
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
(df4['chance of admit']>0.7)&(df4['chance of admit']<0.9)
# Out:
# serial no.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
(df4['chance of admit']>0.7) and (df4['chance of admit']<0.9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 (df4['chance of admit']>0.7) and (df4['chance of admit']<0.9)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df4['chance of admit'].gt(0.7) & df4['chance of admit'].lt(0.9)
# Out:
# serial no.
# 1      False
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398    False
# 399    False
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df4[df4['chance of admit'].gt(0.7)]
#it also create a boolean mask
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# serial no.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
# ...               ...          ...                ...  ...  ...   ...
# 395               329          111                  4  4.5  4.0  9.23
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 400               333          117                  4  5.0  4.0  9.66
#
#             research  chance of admit
# serial no.
# 1                  1             0.92
# ...

# %%
df4[df4['chance of admit'].gt(0.7).lt(0.9)]
#it is function which is better than visvual operator which can give as a boolean mask
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# serial no.
# 5                 314          103                  2  2.0  3.0  8.21
# 8                 308          101                  2  3.0  4.0  7.90
# 9                 302          102                  1  2.0  1.5  8.00
# 10                323          108                  3  3.5  3.0  8.60
# 11                325          106                  3  3.5  4.0  8.40
# ...               ...          ...                ...  ...  ...   ...
# 387               302          101                  2  2.5  3.5  7.96
# 388               307          105                  2  2.0  3.5  8.10
# 389               296           97                  2  1.5  2.0  7.80
# 391               314          102                  2  2.0  2.5  8.24
# 399               312          103                  3  3.5  4.0  8.78
#
#             research  chance of admit
# serial no.
# 5                  0             0.65
# ...

# %%
df=pd.read_csv("Admission_Predict.csv",index_col=0)
df
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
# ...               ...          ...                ...  ...   ...   ...
# 396               324          110                  3  3.5   3.5  9.04
# 397               325          107                  3  3.0   3.5  9.11
# 398               330          116                  4  5.0   4.5  9.45
# 399               312          103                  3  3.5   4.0  8.78
# 400               333          117                  4  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# ...

# %%
#setting index from a column in given data
df['Serial Number']=df.index #this set index as another column
df=df.set_index('Chance of Admit ')
df
# Out:
#                   GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Chance of Admit
# 0.92                    337          118                  4  4.5   4.5  9.65
# 0.76                    324          107                  4  4.0   4.5  8.87
# 0.72                    316          104                  3  3.0   3.5  8.00
# 0.80                    322          110                  3  3.5   2.5  8.67
# 0.65                    314          103                  2  2.0   3.0  8.21
# ...                     ...          ...                ...  ...   ...   ...
# 0.82                    324          110                  3  3.5   3.5  9.04
# 0.84                    325          107                  3  3.0   3.5  9.11
# 0.91                    330          116                  4  5.0   4.5  9.45
# 0.67                    312          103                  3  3.5   4.0  8.78
# 0.95                    333          117                  4  5.0   4.0  9.66
#
# ...

# %%
#now creating new column with sequence wise serial number with the help of reseting index
df=df.reset_index()

# %%
df
# Out:
#      Chance of Admit   GRE Score  TOEFL Score  University Rating  SOP  LOR   \
# 0                0.92        337          118                  4  4.5   4.5
# 1                0.76        324          107                  4  4.0   4.5
# 2                0.72        316          104                  3  3.0   3.5
# 3                0.80        322          110                  3  3.5   2.5
# 4                0.65        314          103                  2  2.0   3.0
# ..                ...        ...          ...                ...  ...   ...
# 395              0.82        324          110                  3  3.5   3.5
# 396              0.84        325          107                  3  3.0   3.5
# 397              0.91        330          116                  4  5.0   4.5
# 398              0.67        312          103                  3  3.5   4.0
# 399              0.95        333          117                  4  5.0   4.0
#
#      CGPA  Research  Serial Number
# ...

# %%
census=pd.read_csv("census.csv",delimiter=",",index_col=False)
a=census

# %%
print(census['SUMLEV'].unique())
#if we want to find a unique values in a column we use unique function and it retirns as an array
# Out:
# [40 50]

# %%
censu=census.loc[census["SUMLEV"]==50]
censu
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# 5         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
censu=['STNAME','CTYNAME','BIRTHS2010','BIRTHS2011','BIRTHS2012','BIRTHS2013','BIRTHS2014','BIRTHS2015','POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']
census=census[censu]
census
# Out:
#        STNAME            CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  \
# 0     Alabama            Alabama       14226       59689       59062
# 1     Alabama     Autauga County         151         636         615
# 2     Alabama     Baldwin County         517        2187        2092
# 3     Alabama     Barbour County          70         335         300
# 4     Alabama        Bibb County          44         266         245
# ...       ...                ...         ...         ...         ...
# 3188  Wyoming  Sweetwater County         167         640         595
# 3189  Wyoming       Teton County          76         259         230
# 3190  Wyoming       Uinta County          73         324         311
# 3191  Wyoming    Washakie County          26         108          90
# 3192  Wyoming      Weston County          26          81          74
#
#       BIRTHS2013  BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  \
# ...

# %%
census=census.set_index(['STNAME','CTYNAME'])
census
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME  CTYNAME
# Alabama Alabama                 14226       59689       59062       57938
#         Autauga County            151         636         615         574
#         Baldwin County            517        2187        2092        2160
#         Barbour County             70         335         300         283
#         Bibb County                44         266         245         259
# ...                               ...         ...         ...         ...
# Wyoming Sweetwater County         167         640         595         657
#         Teton County               76         259         230         261
#         Uinta County               73         324         311         316
#         Washakie County            26         108          90          95
#         Weston County              26          81          74          93
#
# ...
